# %% [markdown]
# ## Dataframe basics:

# %%
import pandas as pd
details = {
    "name": ["raja", "Dhairya", "Raj"],
    "age": [12, 14, 15],
    "classes": [8, 9, 10],
}

details_person=pd.DataFrame()
