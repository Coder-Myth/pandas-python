# %% [markdown]
# ## Import_csv file

# %%
# csv file : file that stores data in a single line format as is easy to be read in excel files (comma seperated value)
# json : js file that stores data as a key value pair (javascript object notation)

import pandas as pd
'''
#  read an csv file
csv_file = pd.read_csv(
    "csvfile.path", encoding="((latin1))<><><>((utf-8))"
)  # run anyone of this
print(csv_file)

'''
# this is a sample code which requiresa file to be created

# same with excel and json file
# gcsfs : a library that reads data from cloud
# Out:
# '\n#  read an csv file\ncsv_file = pd.read_csv(\n    "csvfile.path", encoding="((latin1))<><><>((utf-8))"\n)  # run anyone of this\nprint(csv_file)\n\n'

# %%
#save csv json
details = {
    "name": ["raja", "Dhairya", "Raj"],
    "age": [12, 14, 15],
    "classes": [8, 9, 10],
}
details_dataframe =pd.DataFrame(details)
print(pd.DataFrame(details))

# save this file into csv excel or json file 
save_csv= details_dataframe.to_csv("03", index =False)#index=false means no included index in csv file
# Out:
#       name  age  classes
# 0     raja   12        8
# 1  Dhairya   14        9
# 2      Raj   15       10
